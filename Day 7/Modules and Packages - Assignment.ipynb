# %% [markdown]
# #### 1) Write a module in python with your desired name in your files, this module will have 2 functions with 2 input numbers , namely addition and subtraction [NOTE: If youre using google colab  after writing your file you can see your file in the left file bar which looks like a folder just below sample_data ]  ####

# %% [markdown]
# #### 2) Write extra functionality in both the modules to check whether the module is imported in any other module or it is run on its own (when writing the modules) ####

# %% [markdown]
# #### 3) Write another module in python with your desired name and this module will have 2 functions with 2 input numbers, namely multiplication and division you will have to import the 1st module here and run the functions in these modules itself ####

# %% [markdown]
# #### 4) Run the module 1 and module 2 here using the syntax given earlier ####

# %% [markdown]
# ## THANK YOU ##
