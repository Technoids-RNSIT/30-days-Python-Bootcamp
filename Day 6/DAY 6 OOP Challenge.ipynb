# %% [markdown]
# # Object Oriented Programming Challenge - Solution
#
# For this challenge, create a bank account class that has two attributes:
#
# * owner
# * balance
#
# and two methods:
#
# * deposit
# * withdraw
#
# As an added requirement, withdrawals may not exceed the available balance.
#
# Instantiate your class, make several deposits and withdrawals, and test to make sure the account can't be overdrawn.

# %%
class Account:
    #it has 2 member variables name and balance 
    def __init__(self,name,balance):
        #implement the constructor
        
    def deposit(self,amount):
        #implelemt this function to deposit the given amount and show the current account balance with message
        
    def withdraw(self, amount): 
        #implement this function to display balance after withdrawal of amount with an appropriate message
        #and incase we cant withdraw print an appropriate message
   
    def display(self):
        #implement this function to display the current account balance

# %%
# 1. Instantiate the class

# %%
# 2. Print the object

# %%
# 3. Show the account owner attribute

# %%
# 4. Show the account balance attribute

# %%
# 5. Make a series of deposits and withdrawals

# %%
# 6. Make a withdrawal that exceeds the available balance

# %% [markdown]
# 2) IMPLEMENT a class cylinder with
#
# Variables:
# height
# radius
# Methods:
# volume
# surface_area

# %%
class cylinder:
    def __init__(self,height=1,radius=1): #implement the constructor
        
    def volume(self): #calculate volume of a cylinder and print it 
    
    def surface_area(self): #calculate and print surface area of a cylinder

# %%
# 1. Instantiate the class

# %%
#Show the height attribute

# %%
#Show the radius attribute

# %%
#calculate the volume  of the cylinder

# %%
#calculate the surface area of the cylinder
