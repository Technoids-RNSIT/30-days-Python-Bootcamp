# %% [markdown]
# ### PANDAS Session-2

# %%
#Continued from Session-1 
import pandas as pd

# %%
#create a dataframe
import numpy as np
data = {'First Score':[100,90,np.nan,95,45],
       'Second Score': [30, 45 ,56 , np.nan,78],
       'Third Score': [np.nan, 40,50,80,89],
       'Gender': ['Male','Female','Male','Female','Female']}
df = pd.DataFrame(data)

# %%
df
# Out:
#    First Score  Second Score  Third Score  Gender
# 0        100.0          30.0          NaN    Male
# 1         90.0          45.0         40.0  Female
# 2          NaN          56.0         50.0    Male
# 3         95.0           NaN         80.0  Female
# 4         45.0          78.0         89.0  Female

# %% [markdown]
# #### DataFrame Methods

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.columns
# Out:
# Index(['First Score', 'Second Score', 'Third Score', 'Gender'], dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=5, step=1),
#  Index(['First Score', 'Second Score', 'Third Score', 'Gender'], dtype='object')]

# %%
df.nunique()
# Out:
# First Score     4
# Second Score    4
# Third Score     4
# Gender          2
# dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Female    3
# Male      2
# Name: Gender, dtype: int64

# %%
df.values
# Out:
# array([[100.0, 30.0, nan, 'Male'],
#        [90.0, 45.0, 40.0, 'Female'],
#        [nan, 56.0, 50.0, 'Male'],
#        [95.0, nan, 80.0, 'Female'],
#        [45.0, 78.0, 89.0, 'Female']], dtype=object)

# %%
df.isnull()
# Out:
#    First Score  Second Score  Third Score  Gender
# 0        False         False         True   False
# 1        False         False        False   False
# 2         True         False        False   False
# 3        False          True        False   False
# 4        False         False        False   False

# %%
df.dtypes
# Out:
# First Score     float64
# Second Score    float64
# Third Score     float64
# Gender           object
# dtype: object

# %%
df
# Out:
#    First Score  Second Score  Third Score  Gender
# 0        100.0          30.0          NaN    Male
# 1         90.0          45.0         40.0  Female
# 2          NaN          56.0         50.0    Male
# 3         95.0           NaN         80.0  Female
# 4         45.0          78.0         89.0  Female

# %%
df.sort_values('Gender', axis = 0 , ascending = True , inplace = False , kind = 'quicksort' , na_position = 'last')
# Out:
#    First Score  Second Score  Third Score  Gender
# 1         90.0          45.0         40.0  Female
# 3         95.0           NaN         80.0  Female
# 4         45.0          78.0         89.0  Female
# 0        100.0          30.0          NaN    Male
# 2          NaN          56.0         50.0    Male

# %%
df.sort_values('Third Score', axis= 0 , inplace = False, na_position = 'first')
# Out:
#    First Score  Second Score  Third Score  Gender
# 0        100.0          30.0          NaN    Male
# 1         90.0          45.0         40.0  Female
# 2          NaN          56.0         50.0    Male
# 3         95.0           NaN         80.0  Female
# 4         45.0          78.0         89.0  Female

# %%
df
# Out:
#    First Score  Second Score  Third Score  Gender
# 0        100.0          30.0          NaN    Male
# 1         90.0          45.0         40.0  Female
# 2          NaN          56.0         50.0    Male
# 3         95.0           NaN         80.0  Female
# 4         45.0          78.0         89.0  Female

# %%
data2 = {'First Score':[10 , 20],
       'Second Score': [30 , 40],
       'Third Score': [23, 34],
       'Gender': ['Male','Female']}
df2 = pd.DataFrame(data2)
df2
# Out:
#    First Score  Second Score  Third Score  Gender
# 0           10            30           23    Male
# 1           20            40           34  Female

# %%
df = df.append(df2)

# %%
df
# Out:
#    First Score  Second Score  Third Score  Gender
# 0        100.0          30.0          NaN    Male
# 1         90.0          45.0         40.0  Female
# 2          NaN          56.0         50.0    Male
# 3         95.0           NaN         80.0  Female
# 4         45.0          78.0         89.0  Female
# 0         10.0          30.0         23.0    Male
# 1         20.0          40.0         34.0  Female

# %%
#sort_index
df.sort_index()
# Out:
#    First Score  Second Score  Third Score  Gender
# 0        100.0          30.0          NaN    Male
# 0         10.0          30.0         23.0    Male
# 1         90.0          45.0         40.0  Female
# 1         20.0          40.0         34.0  Female
# 2          NaN          56.0         50.0    Male
# 3         95.0           NaN         80.0  Female
# 4         45.0          78.0         89.0  Female

# %%
df.reset_index()
# Out:
#    index  First Score  Second Score  Third Score  Gender
# 0      0        100.0          30.0          NaN    Male
# 1      1         90.0          45.0         40.0  Female
# 2      2          NaN          56.0         50.0    Male
# 3      3         95.0           NaN         80.0  Female
# 4      4         45.0          78.0         89.0  Female
# 5      0         10.0          30.0         23.0    Male
# 6      1         20.0          40.0         34.0  Female

# %% [markdown]
# ### PANDAS IO TOOLS

# %%
#reading or input
df = pd.read_csv('nba.csv')

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
pd.set_option('display.max.columns', None)

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
df.head(20)
# Out:
#     gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0           1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1           1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2           2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3           2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4           3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5           3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6           4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7           4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8           5  194611020STB   NBA        1     1947  11/2/1946           1
# 9           5  194611020STB   NBA        0     1947  11/2/1946           1
# 10          6  194611030CLR   NBA        1     1947  11/3/1946           2
# ...

# %%
df.tail(10)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126305      63153  201506070GSW   NBA        0     2015   6/7/2015
# 126306      63154  201506090CLE   NBA        1     2015   6/9/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126304          98            1     CLE  Cavaliers   95  1708.1705  1716.8708
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
df.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
df.shape
# Out:
# (126314, 23)

# %%
df.size
# Out:
# 2905222

# %%
126314 * 23
# Out:
# 2905222

# %%
df.ndim
# Out:
# 2

# %%
df.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %%
df.dtypes
# Out:
# gameorder          int64
# game_id           object
# lg_id             object
# _iscopy            int64
# year_id            int64
# date_game         object
# seasongame         int64
# is_playoffs        int64
# team_id           object
# fran_id           object
# pts                int64
# elo_i            float64
# elo_n            float64
# win_equiv        float64
# opp_id            object
# opp_fran          object
# opp_pts            int64
# opp_elo_i        float64
# opp_elo_n        float64
# game_location     object
# game_result       object
# forecast         float64
# notes             object
# dtype: object

# %%
df.values
# Out:
# array([[1, '194611010TRH', 'NBA', ..., 'L', 0.64006501, nan],
#        [1, '194611010TRH', 'NBA', ..., 'W', 0.35993499, nan],
#        [2, '194611020CHS', 'NBA', ..., 'W', 0.63110125, nan],
#        ...,
#        [63156, '201506140GSW', 'NBA', ..., 'L', 0.2344346, nan],
#        [63157, '201506170CLE', 'NBA', ..., 'L', 0.48145005, nan],
#        [63157, '201506170CLE', 'NBA', ..., 'W', 0.51854992, nan]],
#       dtype=object)

# %%
df.nunique()
# Out:
# gameorder         63157
# game_id           63157
# lg_id                 2
# _iscopy               2
# year_id              69
# date_game         12426
# seasongame          108
# is_playoffs           2
# team_id             104
# fran_id              53
# pts                 139
# elo_i            123947
# elo_n            123982
# win_equiv        123857
# opp_id              104
# opp_fran             53
# opp_pts             139
# opp_elo_i        123947
# opp_elo_n        123982
# game_location         3
# game_result           2
# forecast         125039
# notes               231
# dtype: int64

# %%
df['fran_id'].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
df.sort_values('fran_id', axis = 0 , inplace = True , na_position = 'last')

# %%
df
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1604         803  194902030BLB   NBA        0     1949    2/3/1949
# 2389        1195  195001010TRI   NBA        1     1950    1/1/1950
# 949          475  194802040WSC   NBA        1     1948    2/4/1948
# 951          476  194802050BLB   NBA        0     1948    2/5/1948
# 4464        2233  195203100BLB   NBA        0     1952   3/10/1952
# ...          ...           ...   ...      ...      ...         ...
# 27628      13815  197301070BAL   NBA        0     1973    1/7/1973
# 13802       6902  196512250BAL   NBA        0     1966  12/25/1965
# 56429      28215  198701090MIL   NBA        1     1987    1/9/1987
# 27657      13829  197301090POR   NBA        1     1973    1/9/1973
# 55694      27848  198611010CLE   NBA        1     1987   11/1/1986
#
#        seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 1604           42            0     BLB  Baltimore   84  1482.4901  1484.6127
# ...

# %%
df.reset_index()
# Out:
#         index  gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 0        1604        803  194902030BLB   NBA        0     1949    2/3/1949
# 1        2389       1195  195001010TRI   NBA        1     1950    1/1/1950
# 2         949        475  194802040WSC   NBA        1     1948    2/4/1948
# 3         951        476  194802050BLB   NBA        0     1948    2/5/1948
# 4        4464       2233  195203100BLB   NBA        0     1952   3/10/1952
# ...       ...        ...           ...   ...      ...      ...         ...
# 126309  27628      13815  197301070BAL   NBA        0     1973    1/7/1973
# 126310  13802       6902  196512250BAL   NBA        0     1966  12/25/1965
# 126311  56429      28215  198701090MIL   NBA        1     1987    1/9/1987
# 126312  27657      13829  197301090POR   NBA        1     1973    1/9/1973
# 126313  55694      27848  198611010CLE   NBA        1     1987   11/1/1986
#
# ...

# %%
#csv from dataframe\
df.to_csv('sorted_nba.csv', index = False)

# %%
#lets try another dataset
dataset = pd.read_csv('nba_short.csv')

# %%
dataset
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
dataset.shape
# Out:
# (458, 9)

# %%
dataset.head(20)
# Out:
#                        Name            Team  Number Position   Age Height  \
# 0             Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2
# 1               Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6
# 2              John Holland  Boston Celtics    30.0       SG  27.0    6-5
# 3               R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5
# 4             Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10
# 5              Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9
# 6             Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8
# 7              Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0
# 8              Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2
# 9              Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4
# 10          Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9
# 11            Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9
# ...

# %%
dataset.tail(20)
# Out:
#                Name                    Team  Number Position   Age Height  \
# 438    Luis Montero  Portland Trail Blazers    44.0       SG  23.0    6-7
# 439   Mason Plumlee  Portland Trail Blazers    24.0        C  26.0   6-11
# 440   Brian Roberts  Portland Trail Blazers     2.0       PG  30.0    6-1
# 441     Noah Vonleh  Portland Trail Blazers    21.0       PF  20.0    6-9
# 442   Trevor Booker               Utah Jazz    33.0       PF  28.0    6-8
# 443      Trey Burke               Utah Jazz     3.0       PG  23.0    6-1
# 444      Alec Burks               Utah Jazz    10.0       SG  24.0    6-6
# 445      Dante Exum               Utah Jazz    11.0       PG  20.0    6-6
# 446  Derrick Favors               Utah Jazz    15.0       PF  24.0   6-10
# 447     Rudy Gobert               Utah Jazz    27.0        C  23.0    7-1
# 448  Gordon Hayward               Utah Jazz    20.0       SF  26.0    6-8
# 449     Rodney Hood               Utah Jazz     5.0       SG  23.0    6-8
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
dataset.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
dataset.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
dataset
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
dataset['Team'].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Denver Nuggets            15
# Philadelphia 76ers        15
# Indiana Pacers            15
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Washington Wizards        15
# Houston Rockets           15
# Boston Celtics            15
# Charlotte Hornets         15
# Sacramento Kings          15
# Toronto Raptors           15
# Los Angeles Clippers      15
# Oklahoma City Thunder     15
# Los Angeles Lakers        15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Detroit Pistons           15
# Phoenix Suns              15
# Utah Jazz                 15
# Dallas Mavericks          15
# Golden State Warriors     15
# Miami Heat                15
# Minnesota Timberwolves    14
# Orlando Magic             14
# Name: Team, dtype: int64

# %%
dataset.loc[dataset['Team'] == 'Orlando Magic']
# Out:
#                  Name           Team  Number Position   Age Height  Weight  \
# 354    Dewayne Dedmon  Orlando Magic     3.0        C  26.0    7-0   245.0
# 355     Evan Fournier  Orlando Magic    10.0       SG  23.0    6-7   205.0
# 356      Aaron Gordon  Orlando Magic     0.0       PF  20.0    6-9   220.0
# 357     Mario Hezonja  Orlando Magic    23.0       SG  21.0    6-8   218.0
# 358    Ersan Ilyasova  Orlando Magic     7.0       PF  29.0   6-10   235.0
# 359  Brandon Jennings  Orlando Magic    55.0       PG  26.0    6-1   169.0
# 360      Devyn Marble  Orlando Magic    11.0       SF  23.0    6-6   200.0
# 361    Shabazz Napier  Orlando Magic    13.0       PG  24.0    6-1   175.0
# 362  Andrew Nicholson  Orlando Magic    44.0       PF  26.0    6-9   250.0
# 363    Victor Oladipo  Orlando Magic     5.0       SG  24.0    6-4   210.0
# 364     Elfrid Payton  Orlando Magic     4.0       PG  22.0    6-4   185.0
# ...

# %%
#getting the weight of all Orlando Magic players
dataset.loc[dataset['Team'] == 'Orlando Magic' , "Weight"]
# Out:
# 354    245.0
# 355    205.0
# 356    220.0
# 357    218.0
# 358    235.0
# 359    169.0
# 360    200.0
# 361    175.0
# 362    250.0
# 363    210.0
# 364    185.0
# 365    240.0
# 366    260.0
# 367    175.0
# Name: Weight, dtype: float64
